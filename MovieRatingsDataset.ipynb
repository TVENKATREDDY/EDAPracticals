# %%
import pandas as pd
import os
movies=pd.read_csv(r'C:\Venkat\Python\Practice_Material\24thOct_Youtube,EDA,String\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv')
movies
movies.columns=['Film', 'Genre', 'CriticsRatings', 'AudienceRatings',
       'BudgetMillions', 'Year']
#movies

#movies.describe()
movies['Film']
movies.Film=movies.Film.astype('category')
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')  #Year statistics not required so made Year as Category to avoid in describe()
movies.Genre.cat.categories
movies.describe()
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
movies.columns
import warnings
warnings.filterwarnings('ignore')
j=sns.jointplot(data=movies,x='CriticsRatings',y='AudienceRatings')
k=sns.jointplot(data=movies,x='CriticsRatings',y='AudienceRatings',kind='hex')
#movies
sns.set_style('white')
l=sns.displot(movies.AudienceRatings)
#n1=plt.hist(movies.AudienceRatings,bins=15)
#n2=plt.hist(movies.CriticsRatings,bins=20)

#m=sns.distplot(movies.AudienceRatings)
#movies.AudienceRatings
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,label='Action',bins=20)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions,label='Thriller',bins=20)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions,label='Drama',bins=20)
plt.legend()
plt.show()

plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
    movies[movies.Genre=='Thriller'].BudgetMillions,\
    movies[movies.Genre=='Drama'].BudgetMillions, \
    movies[movies.Genre=='Comedy'].BudgetMillions],bins=20,stacked=True
    )
plt.show()
vis1=sns.lmplot(data=movies,x='CriticsRatings',y='AudienceRatings',fit_reg=False)
vis2=sns.lmplot(data=movies,x='CriticsRatings',y='AudienceRatings',fit_reg=False,hue='Genre')
vis3=sns.lmplot(data=movies,x='CriticsRatings',y='AudienceRatings',fit_reg=False,hue='Genre',aspect=1)
k1=sns.kdeplot(data=movies,x='CriticsRatings',y='AudienceRatings')
f,axes=plt.subplots(1,2,figsize=(12,6))
k2=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRatings',ax=axes[0])
k3=sns.kdeplot(data=movies,x='BudgetMillions',y='CriticsRatings',ax=axes[1])
plt.figure()
w=sns.boxplot(data=movies,x='Genre',y='CriticsRatings')
plt.figure()
v1=sns.violinplot(data=movies,x='Genre',y='CriticsRatings')
plt.figure()
w=sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticsRatings')
plt.figure()
v2=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticsRatings')
plt.figure()
f=sns.FacetGrid(data=movies,row='Genre',col='Year',hue='Genre')
plt.scatter(movies.CriticsRatings,movies.AudienceRatings)
plt.figure()
f=sns.FacetGrid(data=movies,row='Genre',col='Year',hue='Genre')
f.map(plt.scatter,'CriticsRatings','AudienceRatings')
plt.figure()
f=sns.FacetGrid(data=movies,row='Genre',col='Year',hue='Genre')
f.map(plt.hist,'BudgetMillions')
plt.figure()
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))
k1 = sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRatings',ax=axes[0,0])
k2 = sns.kdeplot(data=movies,x='BudgetMillions',y='CriticsRatings',ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticsRatings', ax=axes[1,0])

k4 = sns.kdeplot(data=movies,x='CriticsRatings',y='AudienceRatings',ax=axes[1,0])

k4b = sns.kdeplot(data=movies,x='CriticsRatings',y='AudienceRatings',ax = axes[1,1])

plt.show()
