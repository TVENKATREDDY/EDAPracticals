# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
iRisData=pd.read_csv(r'C:\Venkat\Python\Practice_Material\EDA\iris.csv')
iRisData
iRisData.drop('Id',axis=1,inplace=True)
iRisData.head(10)
iRisData.info()
iRisData['Species'].value_counts()
sns.countplot(data=iRisData,x='Species')

plt.show()
fig=sns.jointplot(data=iRisData,x='SepalLengthCm',y='SepalWidthCm')
sns.jointplot(data=iRisData,x='SepalLengthCm',y='SepalWidthCm',kind='reg')
sns.jointplot(data=iRisData,x='SepalLengthCm',y='SepalWidthCm',kind='hex')
# %matplotlib inline
sns.FacetGrid(data=iRisData,hue='Species').map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.barplot(data=iRisData,x='Species',y='PetalLengthCm',order=['Iris-virginica','Iris-versicolor','Iris-setosa'],orient='v',dodge=False)
iRisData.boxplot(by='Species',figsize=(12,6))
fig1=plt.gcf()
fig1.set_size_inches(10,7)
fig1=sns.stripplot(data=iRisData,x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')
ax=sns.boxplot(data=iRisData,x='Species',y='PetalLengthCm')
ax=sns.stripplot(data=iRisData,x='Species',y='PetalLengthCm',jitter=True,edgecolor='gray')
"""
#boxtwo=ax.artists[1]
#boxtwo.set_facecolor('yellow')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[1]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')
boxfour=ax.artists[0]
boxfour.set_facecolor('green')
boxfour.set_edgecolor('black')
"""
plt.show()
fig=sns.violinplot(data=iRisData,x='Species',y='SepalLengthCm')
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(data=iRisData,x='Species',y='PetalLengthCm')
plt.subplot(2,2,2)
sns.violinplot(data=iRisData,x='Species',y='PetalWidthCm')
plt.subplot(2,2,3)
sns.violinplot(data=iRisData,x='Species',y='SepalLengthCm')
plt.subplot(2,2,4)
sns.violinplot(data=iRisData,x='Species',y='SepalWidthCm')
sns.pairplot(data=iRisData,kind='scatter')
sns.pairplot(data=iRisData,hue='Species')
fig=plt.gcf()
fig.set_size_inches(10,7)
#fig=sns.heatmap(iRisData.corr(method='pearson'))
iRisData.hist()
sns.set_style(style='darkgrid')
fig2=plt.figure()
fig2=plt.gcf()
fig2.set_size_inches(10,7)
fig2=sns.swarmplot(data=iRisData,x='Species',y='PetalLengthCm')
fig2=plt.figure()
fig2=plt.gcf()
fig2.set_size_inches(10,7)
ax=sns.violinplot(data=iRisData,x='Species',y='PetalLengthCm',inner=None)
ax=sns.swarmplot(data=iRisData,x='Species',y='PetalLengthCm',color='white',edgecolor='black')
fig=plt.figure()
fig=sns.lmplot(data=iRisData,x='PetalLengthCm',y='PetalWidthCm')
fig=plt.figure()
fig=sns.FacetGrid(data=iRisData,hue='Species').map(sns.kdeplot,'PetalLengthCm').add_legend()
plt.ioff()
fig2=plt.figure()
fig2=sns.boxenplot(data=iRisData,x='Species',y='SepalLengthCm')
sub=iRisData[iRisData['Species']=='Iris-setosa']
fig2=plt.figure()
fig2=sns.kdeplot(data=sub[['SepalLengthCm','SepalWidthCm']],color='plasma')
plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))
k1=sns.boxplot(data=iRisData,x='Species',y='PetalLengthCm',ax=axes[0,0])
k2=sns.violinplot(data=iRisData,x='Species',y='PetalLengthCm',ax=axes[0,1])
k3=sns.stripplot(data=iRisData,x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])
axes[1,1].hist(iRisData.PetalLengthCm,bins=100)
plt.show()
iRisData['Species']=iRisData['Species'].astype('category')
list1=list()
mylabels=list()
for gen in iRisData.Species.cat.categories:
    list1.append(iRisData[iRisData.Species==gen].SepalLengthCm)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()
iRisData.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0,figsize=(12,6))
fig2=plt.figure()
fig2=sns.displot(data=iRisData['SepalLengthCm'])






#,annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# C:\Users\91807\AppData\Local\Temp\ipykernel_4368\1624561893.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   fig1=sns.stripplot(data=iRisData,x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')
# ...
