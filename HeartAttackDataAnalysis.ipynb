# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import warnings
warnings.filterwarnings('ignore')

# %%
heart=pd.read_csv(r"C:\Venkat\Python\Practice_Material\30thOct- Seaborn, Eda practicle\EDA\heart.csv")
heart.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    bool
#  1   sex       303 non-null    bool
#  2   cp        303 non-null    bool
#  3   trestbps  303 non-null    bool
#  4   chol      303 non-null    bool
#  5   fbs       303 non-null    bool
#  6   restecg   303 non-null    bool
#  7   thalach   303 non-null    bool
#  8   exang     303 non-null    bool
#  9   oldpeak   303 non-null    bool
#  10  slope     303 non-null    bool
#  11  ca        303 non-null    bool
#  12  thal      303 non-null    bool
#  13  target    303 non-null    bool
# dtypes: bool(14)
# memory usage: 4.3 KB

# %%
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
sns.set_style('whitegrid')
print('The shape of data: ',heart.shape)
heart.dtypes
# Out:
# The shape of data:  (303, 14)
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart.describe(include=['object'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 heart.describe(include=['object'])
#
# File c:\Users\91807\VSCodeProjects\.venv\lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
heart['target'].unique()
heart['target'].nunique()
# Out:
# 2

# %%
heart['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.countplot(data=heart,x='target')
plt.show()
sns.countplot(data=heart,x='sex',hue='target')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
heart.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
sns.catplot(data=heart,col='sex',x='target',kind='count',height=5,aspect=1)

# %%
ax=sns.catplot(data=heart,x='sex',col='target',kind='count',height=5,aspect=1)

# %%
sns.countplot(data=heart,x='target',palette='Set3')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
heart.groupby('fbs')['target'].value_counts()
sns.countplot(data=heart,x='fbs',hue='target')
plt.show()

# %%
#Bivariate
correlation=heart.corr()
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
heart['cp'].value_counts()
heart['cp'].dtypes
# Out:
# dtype('int64')

# %%
#f,ax=plt.subplots(figsize=(8,6))
sns.countplot(data=heart,x='cp')
plt.show()

# %%
heart.groupby('cp')['target'].value_counts()
sns.countplot(data=heart,x='cp',hue='target')
plt.show()
sns.catplot(data=heart,col='cp',x='target',kind='count',height=6,aspect=1)

# %%
heart['thalach'].nunique()
heart.groupby('thalach')['target'].value_counts()
# Out:
# thalach  target
# 71       0         1
# 88       0         1
# 90       0         1
# 95       0         1
# 96       0         1
#                   ..
# 190      1         1
# 192      1         1
# 194      1         1
# 195      0         1
# 202      1         1
# Name: count, Length: 138, dtype: int64

# %%
f,ax=plt.subplots(figsize=(10,6))
ax=sns.displot(data=heart['thalach'])
#plt.show()

# %%
x=pd.Series(heart['thalach'],name='thalach variable')
sns.kdeplot(x,shade=True,color='r')
plt.show()

# %%
sns.displot(heart['thalach'],kde=False,rug=True,bins=10)

# %%
sns.stripplot(data=heart,x='target',y='thalach',jitter=0.01)
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
sns.boxplot(data=heart,x='target',y='thalach')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
#MultiVariate
plt.figure(figsize=(16,12))
plt.title('Correlation Heat Map of Heart Desease DataSet')
a=sns.heatmap(correlation,square=True,annot=True,fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=30)
plt.show()

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(data=heart[num_var],kind='scatter',diag_kind='hist')

# %%
heart['age'].describe()
sns.displot(data=heart['age'],bins=10)

# %%
sns.stripplot(data=heart,x='target',y='age')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.boxplot(data=heart,x='target',y='age')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.scatterplot(data=heart,x='age',y='trestbps')
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.regplot(data=heart,x='age',y='trestbps')
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.scatterplot(data=heart,x='age',y='chol')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.regplot(data=heart,x='age',y='chol')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.scatterplot(data=heart,x='chol',y='thalach')
plt.show()
sns.regplot(data=heart,x='chol',y='thalach')
plt.show()

# %%
sns.boxplot(data=heart['age'])
# Out:
# <Axes: ylabel='age'>

# %%
heart['trestbps'].describe()
sns.boxplot(data=heart['trestbps'])
# Out:
# <Axes: ylabel='trestbps'>

# %%
heart['chol'].describe()
sns.boxplot(data=heart['chol'])
# Out:
# <Axes: ylabel='chol'>

# %%
heart['thalach'].describe()
sns.boxplot(data=heart['thalach'])
# Out:
# <Axes: ylabel='thalach'>
