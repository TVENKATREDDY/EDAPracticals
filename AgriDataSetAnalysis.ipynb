# %%
AgriDataSet Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy as sc
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
agriData=pd.read_csv(r'C:\Venkat\Python\Practice_Material\Kaggle_DataSets\agriculture_dataset.csv')

# %%
agriData.describe()
# Out:
#        Farm_Area(acres)  Fertilizer_Used(tons)  Pesticide_Used(kg)  \
# count         50.000000              50.000000           50.000000
# mean         254.963800               4.905400            2.398000
# std          139.417782               2.732689            1.438613
# min           12.500000               0.500000            0.140000
# 25%          135.710000               2.437500            0.972500
# 50%          281.980000               5.045000            2.330000
# 75%          368.107500               6.885000            3.417500
# max          483.880000               9.960000            4.990000
#
#        Yield(tons)  Water_Usage(cubic meters)
# count    50.000000                  50.000000
# mean     27.059200               56724.295600
# std      13.345789               27264.992053
# min       3.860000                5869.750000
# 25%      16.190000               37818.152500
# 50%      28.970000               54097.075000
# ...

# %%
agriData.shape
# Out:
# (50, 10)

# %%
agriData.columns
# Out:
# Index(['Farm_ID', 'Crop_Type', 'Farm_Area(acres)', 'Irrigation_Type',
#        'Fertilizer_Used(tons)', 'Pesticide_Used(kg)', 'Yield(tons)',
#        'Soil_Type', 'Season', 'Water_Usage(cubic meters)'],
#       dtype='object')

# %%
agriData[['Crop_Type','Irrigation_Type']]
# Out:
#     Crop_Type Irrigation_Type
# 0      Cotton       Sprinkler
# 1      Carrot          Manual
# 2   Sugarcane           Flood
# 3      Tomato        Rain-fed
# 4      Tomato       Sprinkler
# 5   Sugarcane       Sprinkler
# 6     Soybean            Drip
# 7        Rice            Drip
# 8       Maize            Drip
# 9     Soybean            Drip
# 10       Rice            Drip
# 11  Sugarcane           Flood
# 12      Wheat            Drip
# 13       Rice           Flood
# 14  Sugarcane        Rain-fed
# 15     Barley           Flood
# 16     Carrot          Manual
# 17      Maize        Rain-fed
# 18      Maize            Drip
# 19     Barley       Sprinkler
# 20     Cotton            Drip
# 21      Wheat           Flood
# 22     Potato            Drip
# 23       Rice            Drip
# 24     Barley           Flood
# 25      Wheat           Flood
# 26     Cotton        Rain-fed
# 27     Tomato           Flood
# 28      Wheat          Manual
# 29     Potato        Rain-fed
# ...

# %%
sns.displot(agriData['Farm_Area(acres)'],kde=True)

# %%
sns.histplot(agriData['Farm_Area(acres)'])
# Out:
# <Axes: xlabel='Farm_Area(acres)', ylabel='Count'>

# %%
agriData[agriData['Farm_Area(acres)'] <=90]['Farm_Area(acres)']
# Out:
# 1     18.67
# 5     12.50
# 15    60.22
# 19    58.85
# 22    15.67
# 24    75.64
# 42    78.79
# 43    84.12
# 47    77.39
# Name: Farm_Area(acres), dtype: float64

# %%
agriData['Fertilizer_Used(tons)']
# Out:
# 0     8.14
# 1     4.77
# 2     2.91
# 3     3.32
# 4     8.33
# 5     6.42
# 6     1.83
# 7     5.18
# 8     0.57
# 9     2.18
# 10    8.02
# 11    3.01
# 12    5.26
# 13    1.01
# 14    5.39
# 15    2.19
# 16    5.89
# 17    4.91
# 18    1.09
# 19    3.61
# 20    5.95
# 21    6.95
# 22    9.95
# 23    6.31
# 24    6.69
# 25    5.85
# 26    0.50
# 27    7.32
# 28    1.79
# 29    8.91
# 30    5.89
# 31    8.40
# 32    7.79
# 33    4.75
# 34    8.57
# 35    4.35
# 36    1.18
# 37    5.71
# 38    9.96
# 39    2.85
# 40    8.18
# 41    0.78
# 42    1.35
# 43    4.64
# 44    5.24
# 45    1.80
# 46    3.86
# 47    9.34
# 48    2.30
# 49    4.08
# Name: Fertilizer_Used(tons), dtype: float64

# %%
sns.histplot(agriData[agriData['Fertilizer_Used(tons)']<2]['Fertilizer_Used(tons)'])
# Out:
# <Axes: xlabel='Fertilizer_Used(tons)', ylabel='Count'>

# %%
agriData[agriData['Fertilizer_Used(tons)']<2]
# Out:
#    Farm_ID  Crop_Type  Farm_Area(acres) Irrigation_Type  \
# 6     F007    Soybean            360.06            Drip
# 8     F009      Maize            389.37            Drip
# 13    F014       Rice            246.02           Flood
# 18    F019      Maize            460.93            Drip
# 26    F027     Cotton            375.10        Rain-fed
# 28    F029      Wheat            288.52          Manual
# 36    F037    Soybean            156.10          Manual
# 41    F042  Sugarcane            418.99       Sprinkler
# 42    F043     Cotton             78.79           Flood
# 45    F046     Carrot            112.80       Sprinkler
#
#     Fertilizer_Used(tons)  Pesticide_Used(kg)  Yield(tons) Soil_Type  Season  \
# 6                    1.83                2.37        44.93     Sandy    Rabi
# 8                    0.57                4.93         3.86     Peaty    Rabi
# 13                   1.01                3.45        11.38     Sandy    Rabi
# ...

# %%
sns.displot(agriData['Pesticide_Used(kg)'],bins=10,kde=True)

# %%
sns.histplot(agriData['Water_Usage(cubic meters)'],bins=10,kde=True)
# Out:
# <Axes: xlabel='Water_Usage(cubic meters)', ylabel='Count'>

# %%
agriNumeric=agriData.select_dtypes(include=['number'])
agriNumeric
corrmat=agriNumeric.corr()

# %%
sns.heatmap(corrmat,vmax=.9,square=True)
# Out:
# <Axes: >

# %%
agriData.columns.to_list()
# Out:
# ['Farm_ID',
#  'Crop_Type',
#  'Farm_Area(acres)',
#  'Irrigation_Type',
#  'Fertilizer_Used(tons)',
#  'Pesticide_Used(kg)',
#  'Yield(tons)',
#  'Soil_Type',
#  'Season',
#  'Water_Usage(cubic meters)']

# %%
for col in agriData:
    sns.histplot(data=agriData,x=col,kde=True)
    plt.show()

# %%
for col in agriData:
    if agriData[col].dtype == 'O':
        sns.countplot(x=col,data=agriData)
        plt.show()

# %%
agriData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Farm_ID                    50 non-null     object
#  1   Crop_Type                  50 non-null     object
#  2   Farm_Area(acres)           50 non-null     float64
#  3   Irrigation_Type            50 non-null     object
#  4   Fertilizer_Used(tons)      50 non-null     float64
#  5   Pesticide_Used(kg)         50 non-null     float64
#  6   Yield(tons)                50 non-null     float64
#  7   Soil_Type                  50 non-null     object
#  8   Season                     50 non-null     object
#  9   Water_Usage(cubic meters)  50 non-null     float64
# dtypes: float64(5), object(5)
# memory usage: 4.0+ KB

# %%
#Define the Columns you want to plot
columns =['Farm_ID',
 'Crop_Type',
 'Farm_Area(acres)',
 'Irrigation_Type',
 'Fertilizer_Used(tons)',
 'Pesticide_Used(kg)',
 'Yield(tons)',
 'Soil_Type',
 'Season',
 'Water_Usage(cubic meters)','Test']
#Iterate through each column and create a bar or histpgram
for col in columns:
    if col not in agriData.columns:
        print(f"Column {col} not present in the dataframe")
        continue
    if agriData[col].dtype ==  'object' or agriData[col].dtype.name=='category':
        column_counts=agriData[col].value_counts().reset_index()
        #column_counts.columns=[col,'count']
        print(column_counts)
    #print(column_counts)
        #fig=px.bar(column_counts,x=col,y='count',title=f'Distribution of {col}',labels={col: col,'count':'count'},text='count')
        #ig.show()
# Out:
#    Farm_ID  count
# 0     F001      1
# 1     F002      1
# 2     F003      1
# 3     F004      1
# 4     F005      1
# 5     F006      1
# 6     F007      1
# 7     F008      1
# 8     F009      1
# 9     F010      1
# 10    F011      1
# 11    F012      1
# 12    F013      1
# 13    F014      1
# 14    F015      1
# 15    F016      1
# 16    F017      1
# 17    F018      1
# 18    F019      1
# 19    F020      1
# 20    F021      1
# 21    F022      1
# 22    F023      1
# 23    F024      1
# 24    F025      1
# 25    F026      1
# 26    F027      1
# 27    F028      1
# 28    F029      1
# 29    F030      1
# 30    F031      1
# 31    F032      1
# 32    F033      1
# 33    F034      1
# 34    F035      1
# 35    F036      1
# 36    F037      1
# 37    F038      1
# 38    F039      1
# 39    F040      1
# 40    F041      1
# 41    F042      1
# 42    F043      1
# 43    F044      1
# 44    F045      1
# 45    F046      1
# 46    F047      1
# 47    F048      1
# 48    F049      1
# ...

# %%
column_counts.tail(10)
# Out:
#    Season  count
# 0    Zaid     23
# 1  Kharif     16
# 2    Rabi     11

# %%
agriData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Farm_ID                    50 non-null     object
#  1   Crop_Type                  50 non-null     object
#  2   Farm_Area(acres)           50 non-null     float64
#  3   Irrigation_Type            50 non-null     object
#  4   Fertilizer_Used(tons)      50 non-null     float64
#  5   Pesticide_Used(kg)         50 non-null     float64
#  6   Yield(tons)                50 non-null     float64
#  7   Soil_Type                  50 non-null     object
#  8   Season                     50 non-null     object
#  9   Water_Usage(cubic meters)  50 non-null     float64
# dtypes: float64(5), object(5)
# memory usage: 4.0+ KB
